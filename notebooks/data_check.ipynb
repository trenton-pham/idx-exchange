# %%
import pandas as pd

# %%
df = pd.read_csv("../data/cleaned/CRMLSListing_cleaned.csv")
df
# Out:
# /var/folders/kg/syn5dsfn40l0n2qfhr_8whqh0000gn/T/ipykernel_29689/831452915.py:1: DtypeWarning: Columns (0: BuyerAgencyCompensationType, 1: FireplaceYN) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/cleaned/CRMLSListing_cleaned.csv")
#         OriginalListPrice  ListingKey CloseDate  ClosePrice   Latitude  \
# 0               1340000.0  1074973329       NaN         NaN  34.052207
# 1               2500000.0  1074954552       NaN         NaN  33.496363
# 2               3150000.0  1074936537       NaN         NaN  34.119345
# 3               3090000.0  1074917818       NaN         NaN  33.984057
# 4              12725000.0  1074143166       NaN         NaN  33.607583
# ...                   ...         ...       ...         ...        ...
# 557311           345000.0  1156426770       NaN         NaN  32.773338
# 557312          1395000.0  1155742988       NaN         NaN  33.482763
# ...

# %%
df.columns
# Out:
# Index(['OriginalListPrice', 'ListingKey', 'CloseDate', 'ClosePrice',
#        'Latitude', 'Longitude', 'UnparsedAddress', 'PropertyType',
#        'LivingArea', 'ListPrice', 'DaysOnMarket', 'ListOfficeName',
#        'BuyerOfficeName', 'CoListOfficeName', 'ListAgentFullName',
#        'CoListAgentFirstName', 'CoListAgentLastName', 'BuyerAgentMlsId',
#        'BuyerAgentFirstName', 'BuyerAgentLastName', 'AssociationFeeFrequency',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'CountyOrParish', 'MlsStatus',
#        'ElementarySchool', 'AttachedGarageYN', 'ParkingTotal',
#        'PropertySubType', 'LotSizeAcres', 'SubdivisionName', 'BuyerOfficeAOR',
#        'YearBuilt', 'BuyerAgencyCompensationType', 'StreetNumberNumeric',
#        'ListingId', 'BathroomsTotalInteger', 'City', 'BuyerAgencyCompensation',
#        'BedroomsTotal', 'ContractStatusChangeDate', 'PurchaseContractDate',
#        'ListingContractDate', 'StateOrProvince', 'MiddleOrJuniorSchool',
# ...

# %%
df["year_month"]
# Out:
# 0         2024-01
# 1         2024-01
# 2         2024-01
# 3         2024-01
# 4         2024-01
#            ...
# 557311    2026-07
# 557312    2026-07
# 557313    2026-07
# 557314    2026-07
# 557315    2026-07
# Name: year_month, Length: 557316, dtype: str

# %%
df.groupby("year_month").size()
# Out:
# year_month
# 2024-01    12763
# 2024-02    12797
# 2024-03    14715
# 2024-04    16580
# 2024-05    12557
# 2024-06     4662
# 2024-07     4433
# 2024-08    17602
# 2024-09    21956
# 2024-10    21677
# 2024-11    14959
# 2024-12    10566
# 2025-01    22405
# 2025-02    21649
# 2025-03    24722
# 2025-04    26383
# 2025-05    26036
# 2025-06    16886
# 2025-07    17042
# 2025-08    15508
# 2025-09    16620
# 2025-10    16958
# 2025-11    12031
# 2025-12    10308
# 2026-01    21800
# 2026-02    20529
# 2026-03    25246
# 2026-04    26129
# 2026-05    24106
# 2026-06    23765
# 2026-07    23926
# dtype: int64

# %%
print(df["ListingContractDate"].min())
print(df["ListingContractDate"].max())
# Out:
# 2024-01-01
# 2026-07-31

# %%
df["YEAR"] = df["ListingContractDate"].str[:4]
df["YEAR"].value_counts()
# Out:
# YEAR
# 2025    226548
# 2026    165501
# 2024    165267
# Name: count, dtype: int64

# %%
df["ListingContractDate"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["CloseDate"].isnull().sum()
# Out:
# np.int64(411123)
