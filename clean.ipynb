# %%
from pathlib import Path

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
listing_path = Path("data/mortgage/CRMLSListing_202401_202605_with_mortgage.csv")
sold_path = Path("data/mortgage/CRMLSSold_202401_202605_with_mortgage.csv")

# %%
listing = pd.read_csv(listing_path)
listing
# Out:
# /var/folders/kg/syn5dsfn40l0n2qfhr_8whqh0000gn/T/ipykernel_58660/521241561.py:1: DtypeWarning: Columns (0: ListAgentEmail) have mixed types. Specify dtype option on import or set low_memory=False.
#   listing = pd.read_csv(listing_path)
#         OriginalListPrice  ListingKey                        ListAgentEmail  \
# 0               1340000.0  1074973329                    haleh360@Gmail.com
# 1               2500000.0  1074954552  Reneechen@yourhomesoldguaranteed.com
# 2               3150000.0  1074936537                      anader@dppre.com
# 3               3090000.0  1074917818                  QIANYU0607@GMAIL.COM
# 4              12725000.0  1074143166          jeff.williams@pacificsir.com
# ...                   ...         ...                                   ...
# 616067           849000.0  1156787989                                   NaN
# 616068          1375000.0  1156489602                                   NaN
# 616069           649900.0  1154722990                                   NaN
# 616070           795000.0  1153448926                                   NaN
# 616071           675800.0  1108634530                                   NaN
#
#        ListAgentFirstName ListAgentLastName   Latitude   Longitude  \
# 0                   Haleh       Dowlatshahi  34.052207 -118.408445
# 1                   Renee              Chen  33.496363 -117.691677
# 2                Margaret             Nader  34.119345 -118.111254
# 3                  QIANYU              GUAN  33.984057 -117.802819
# 4                    Jeff          Williams  33.607583 -117.887743
# ...                   ...               ...        ...         ...
# 616067             Edward            Zamora  37.950161 -121.659890
# 616068              Jezer        Manalastas  32.629353 -116.949771
# 616069           Benjamin       Diaz-Habben  38.114716 -122.239396
# 616070               Jace           Coleman  32.837643 -116.765217
# 616071             Sharon       Quisenberry  33.040756 -116.595224
#
#                       UnparsedAddress PropertyType  LivingArea  ...  \
# 0       2220 Avenue Of The Stars 2704  Residential      1301.0  ...
# 1                        16 Palisades  Residential      2788.0  ...
# 2                   1615 Waverly Road  Residential      3250.0  ...
# 3              2250 Indian Creek Road  Residential      7456.0  ...
# 4                     317 E. Bayfront  Residential      2321.0  ...
# ...                               ...          ...         ...  ...
# 616067            1691 Eden Plains Rd  Residential      2222.0  ...
# 616068           1561 Copper Penny Dr  Residential      3058.0  ...
# 616069             21 Monte Vista Ave  Residential      1970.0  ...
# 616070               1242 Marshall Rd  Residential      1846.0  ...
# 616071             1626 Frisius Drive  Residential      1690.0  ...
#
#         LotSizeArea  MainLevelBedrooms NewConstructionYN GarageSpaces  \
# 0          177861.0                NaN             False          NaN
# 1            5300.0                0.0             False          3.0
# 2            9404.0                NaN               NaN          2.0
# 3           58232.0                1.0             False          4.0
# 4            2250.0                3.0             False          2.0
# ...             ...                ...               ...          ...
# 616067      20909.0                NaN             False          2.0
# 616068          NaN                NaN             False          3.0
# 616069       7405.0                NaN             False          0.0
# 616070      37897.0                NaN             False          1.0
# 616071      28749.0                1.0             False          0.0
#
#            HighSchoolDistrict PostalCode AssociationFee LotSizeSquareFeet  \
# 0                         NaN      90067        2105.00          177861.0
# 1          Capistrano Unified      92677         254.00            5300.0
# 2                         NaN      91108            NaN            9404.0
# 3       Walnut Valley Unified      91765         295.95           58232.0
# 4        Newport Mesa Unified      92662           0.00            2250.0
# ...                       ...        ...            ...               ...
# 616067                    NaN      94513            NaN           20909.0
# 616068                    NaN      91915         125.00               NaN
# 616069                    NaN      94590            NaN            7405.0
# 616070                    NaN      91901            NaN           37897.0
# 616071     Julian High School      92036           0.00           28749.0
#
#                     UnparsedAddress.1 year_month
# 0       2220 Avenue Of The Stars 2704    2024-01
# 1                        16 Palisades    2024-01
# 2                   1615 Waverly Road    2024-01
# 3              2250 Indian Creek Road    2024-01
# 4                     317 E. Bayfront    2024-01
# ...                               ...        ...
# 616067            1691 Eden Plains Rd    2026-06
# 616068           1561 Copper Penny Dr    2026-06
# 616069             21 Monte Vista Ave    2026-06
# 616070               1242 Marshall Rd    2026-06
# 616071             1626 Frisius Drive    2026-06
#
# [616072 rows x 52 columns]

# %%
sold = pd.read_csv(sold_path)
sold
# Out:
# /var/folders/kg/syn5dsfn40l0n2qfhr_8whqh0000gn/T/ipykernel_58660/4239177719.py:1: DtypeWarning: Columns (0: ListAgentEmail, 1: BuyerAgentAOR, 2: ListAgentAOR) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold = pd.read_csv(sold_path)
#                     Flooring ViewYN PoolPrivateYN  OriginalListPrice  \
# 0           Carpet,Tile,Wood   True         False           499000.0
# 1                        NaN  False         False           759900.0
# 2                        NaN  False         False           739900.0
# 3                        NaN   True         False          2100000.0
# 4                       Tile   True         False          1950000.0
# ...                      ...    ...           ...                ...
# 447959                   NaN   True         False          1388000.0
# 447960                   NaN   True          True           919900.0
# 447961       Carpet,Laminate    NaN         False           975000.0
# 447962  Carpet,Laminate,Wood   True         False           649999.0
# 447963                   NaN   True         False          6989995.0
#
#         ListingKey                  ListAgentEmail   CloseDate  ClosePrice  \
# 0        551985747           jwachter@cbnorcal.com  2024-01-26    240000.0
# 1        522107581            mdarwich12@gmail.com  2024-01-05    815000.0
# 2        510919001            mdarwich12@gmail.com  2024-01-05    810000.0
# 3       1067652762  jenniferarielkennedy@gmail.com  2024-01-02   2100000.0
# 4       1063453216               kira@mendosir.com  2024-01-22   1950000.0
# ...            ...                             ...         ...         ...
# 447959  1060097689                             NaN  2026-06-30  13000000.0
# 447960  1037789100                             NaN  2026-06-30    850000.0
# 447961  1035814040                             NaN  2026-06-11    595000.0
# 447962  1023191564                             NaN  2026-06-30    615000.0
# 447963  1014091927                             NaN  2026-06-26   3000000.0
#
#        ListAgentFirstName ListAgentLastName  ...  MainLevelBedrooms  \
# 0                    Joan           Wachter  ...                NaN
# 1                 Michael           Darwich  ...                NaN
# 2                 Michael           Darwich  ...                NaN
# 3                Jennifer           Kennedy  ...                3.0
# 4                    Kira             Meade  ...                NaN
# ...                   ...               ...  ...                ...
# 447959           Reynaldo           Alvaran  ...                2.0
# 447960              Hervi           Estrada  ...                1.0
# 447961         Phillip L.              Fair  ...                NaN
# 447962              Hervi           Estrada  ...                2.0
# 447963          Billie Jo             Ralls  ...                3.0
#
#         NewConstructionYN GarageSpaces         HighSchoolDistrict  PostalCode  \
# 0                   False          1.0                      Other       94401
# 1                   False          2.0                        NaN       91950
# 2                   False          2.0                        NaN       91950
# 3                   False          3.0   San Luis Coastal Unified       93401
# 4                     NaN          2.0                        NaN       95437
# ...                   ...          ...                        ...         ...
# 447959              False          1.0        Los Angeles Unified       90046
# 447960              False          3.0      Antelope Valley Union       93536
# 447961              False          1.0                    Oakland       94608
# 447962              False          2.0      Antelope Valley Union       93551
# 447963              False          1.0  Paso Robles Joint Unified       93461
#
#         AssociationFee  LotSizeSquareFeet       BuyerAgentAOR  \
# 0               6472.0                NaN                 NaN
# 1                  NaN                NaN                 NaN
# 2                  NaN                NaN                 NaN
# 3                  0.0            11219.0                 NaN
# 4                  NaN            74487.6                 NaN
# ...                ...                ...                 ...
# 447959             0.0             7103.0         TriCounties
# 447960             0.0            30228.0           Southland
# 447961             NaN             4389.0             Oakland
# 447962             0.0           113797.0           Southland
# 447963             0.0        106836562.8  NorthSanLuisObispo
#
#               ListAgentAOR year_month
# 0                      NaN    2024-01
# 1                      NaN    2024-01
# 2                      NaN    2024-01
# 3                      NaN    2024-01
# 4                      NaN    2024-01
# ...                    ...        ...
# 447959         TriCounties    2026-06
# 447960           Southland    2026-06
# 447961             Oakland    2026-06
# 447962           Southland    2026-06
# 447963  NorthSanLuisObispo    2026-06
#
# [447964 rows x 56 columns]

# %%
listing.columns
# Out:
# Index(['OriginalListPrice', 'ListingKey', 'ListAgentEmail',
#        'ListAgentFirstName', 'ListAgentLastName', 'Latitude', 'Longitude',
#        'UnparsedAddress', 'PropertyType', 'LivingArea', 'ListPrice',
#        'DaysOnMarket', 'ListOfficeName', 'ListAgentFullName',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'CountyOrParish', 'PropertyType.1',
#        'MlsStatus', 'ListAgentFirstName.1', 'AttachedGarageYN', 'ParkingTotal',
#        'PropertySubType', 'LotSizeAcres', 'YearBuilt', 'DaysOnMarket.1',
#        'StreetNumberNumeric', 'LivingArea.1', 'ListingId',
#        'BathroomsTotalInteger', 'City', 'BedroomsTotal',
#        'ContractStatusChangeDate', 'Longitude.1', 'ListingContractDate',
#        'Latitude.1', 'ListPrice.1', 'StateOrProvince', 'FireplaceYN',
#        'Stories', 'Levels', 'ListAgentLastName.1', 'LotSizeArea',
#        'MainLevelBedrooms', 'NewConstructionYN', 'GarageSpaces',
#        'HighSchoolDistrict', 'PostalCode', 'AssociationFee',
#        'LotSizeSquareFeet', 'UnparsedAddress.1', 'year_month'],
#       dtype='str')

# %%
sold.columns
# Out:
# Index(['Flooring', 'ViewYN', 'PoolPrivateYN', 'OriginalListPrice',
#        'ListingKey', 'ListAgentEmail', 'CloseDate', 'ClosePrice',
#        'ListAgentFirstName', 'ListAgentLastName', 'Latitude', 'Longitude',
#        'UnparsedAddress', 'PropertyType', 'LivingArea', 'ListPrice',
#        'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName',
#        'ListAgentFullName', 'BuyerAgentMlsId', 'BuyerAgentFirstName',
#        'BuyerAgentLastName', 'ListingKeyNumeric', 'MLSAreaMajor',
#        'CountyOrParish', 'MlsStatus', 'AttachedGarageYN', 'ParkingTotal',
#        'PropertySubType', 'LotSizeAcres', 'BuyerOfficeAOR', 'YearBuilt',
#        'StreetNumberNumeric', 'ListingId', 'BathroomsTotalInteger', 'City',
#        'BedroomsTotal', 'ContractStatusChangeDate', 'PurchaseContractDate',
#        'ListingContractDate', 'StateOrProvince', 'FireplaceYN', 'Stories',
#        'Levels', 'LotSizeArea', 'MainLevelBedrooms', 'NewConstructionYN',
#        'GarageSpaces', 'HighSchoolDistrict', 'PostalCode', 'AssociationFee',
#        'LotSizeSquareFeet', 'BuyerAgentAOR', 'ListAgentAOR', 'year_month'],
#       dtype='str')

# %% [markdown]
# ### Note on metadata fields:
# - Keys: ListingKey, ListingKeyNumeric, ListingId
# - Address: UnparsedAddress, StreetNumberNumeric
# - Agent/list: ListAgentEmail, ListAgentFirstName, ListAgentLastName, ListAgentFullName, ListOfficeName
# - Buyer-side: BuyerAgentFirstName, BuyerAgentLastName, BuyerAgentMlsId, BuyerOfficeName, BuyerOfficeAOR, BuyerAgentAOR
# - Location (State): StateOrProvince

# %% [markdown]
# ### Note on market analysis fields:
# - Price: OriginalListPrice, ListPrice, ClosePrice
# - Timing: CloseDate, PurchaseContractDate, ListingContractDate, DaysOnMarket, year_month
# - Geography: CountyOrParish, City, PostalCode, MLSAreaMajor, HighSchoolDistrict
# - Location (coordinates): Latitude, Longitude
# - Property Details: PropertySubType, LivingArea, BedroomsTotal, BathroomsTotalInteger, YearBuilt, LotSizeSquareFeet, LotSizeAcres, GarageSpaces, ParkingTotal, AttachedGarageYN, Stories, Levels, MainLevelBedrooms, AssociationFee, NewConstructionYN, FireplaceYN, iewYN, PoolPrivateYN, Flooring

# %% [markdown]
# ### Converting date columns into datetime

# %%
def to_datetime(df, date_columns): 

    df[date_columns] = df[date_columns].apply(pd.to_datetime, errors="coerce")

    # df["year_month"] = pd.to_datetime(
    #     df["year_month"], format="%Y-%m", errors="coerce")
    # df["Month"] = df["year_month"].dt.month
    # df["Year"] = df["year_month"].dt.year

    return df

# %%
listing_date_columns = ["ListingContractDate", "ContractStatusChangeDate"]
sold_date_columns = date_columns = [
        "ListingContractDate",
        "PurchaseContractDate",
        "CloseDate",
        "ContractStatusChangeDate",
    ]

# %%
listing = to_datetime(listing, listing_date_columns)
sold = to_datetime(sold, sold_date_columns)

# %% [markdown]
# ### Flagging date consistency violations

# %%
sold["listing_after_close_flag"] = sold["ListingContractDate"] > sold["CloseDate"]
sold["purchase_after_close_flag"] = sold["PurchaseContractDate"] > sold["CloseDate"]
sold["negative_timeline_flag"] = sold["ListingContractDate"] > sold["PurchaseContractDate"]

timeline_flag_columns = [
    "listing_after_close_flag",
    "purchase_after_close_flag",
    "negative_timeline_flag",
]
sold[timeline_flag_columns].sum()
# Out:
# listing_after_close_flag      67
# purchase_after_close_flag    239
# negative_timeline_flag       290
# dtype: int64

# %% [markdown]
# ### Dropping redundant list agent columns

# %%
def list_agent(df):
    columns = ["ListAgentEmail", "ListAgentFirstName", "ListAgentLastName"]
    df.drop(columns=columns, inplace=True)
    return df

# %%
listing = list_agent(listing)
sold = list_agent(sold)

# %% [markdown]
# ### Filtering coordinates to purely California

# %%
city_path = Path("data/city_boundaries/City_and_County_Boundaries.geojson")
city_gdf = gpd.read_file(city_path)
city_gdf = city_gdf.set_crs("EPSG:4326")

california_boundary = city_gdf.dissolve()

def filter_coordinates(df):
    df = df.dropna(subset=["Latitude", "Longitude"])
    
    df_points = gpd.GeoDataFrame(
        df,
        geometry=gpd.points_from_xy(df["Longitude"], df["Latitude"]),
        crs="EPSG:4326",
    )

    df = (gpd.sjoin(
            df_points,
            california_boundary[["geometry"]],
            how="inner",
            predicate="within",
        )
        .drop(columns=["geometry", "index_right"])
        .pipe(pd.DataFrame)
    )

    return df

# %%
listing = filter_coordinates(listing)
sold = filter_coordinates(sold)

# %%
def filter_nono_values(df, columns):
    for column in columns:
        df = df[df[column] >= 0]
    return df

# %%
listing_columns = ["LivingArea", "DaysOnMarket", "BedroomsTotal", 
               "BathroomsTotalInteger"]

sold_columns = listing_columns + ["ClosePrice"]

listing = filter_nono_values(listing, listing_columns)
sold = filter_nono_values(sold, sold_columns)

# %%
listing
# Out:
#         OriginalListPrice  ListingKey   Latitude   Longitude  \
# 0               1340000.0  1074973329  34.052207 -118.408445
# 1               2500000.0  1074954552  33.496363 -117.691677
# 2               3150000.0  1074936537  34.119345 -118.111254
# 3               3090000.0  1074917818  33.984057 -117.802819
# 4              12725000.0  1074143166  33.607583 -117.887743
# ...                   ...         ...        ...         ...
# 616067           849000.0  1156787989  37.950161 -121.659890
# 616068          1375000.0  1156489602  32.629353 -116.949771
# 616069           649900.0  1154722990  38.114716 -122.239396
# 616070           795000.0  1153448926  32.837643 -116.765217
# 616071           675800.0  1108634530  33.040756 -116.595224
#
#                       UnparsedAddress PropertyType  LivingArea   ListPrice  \
# 0       2220 Avenue Of The Stars 2704  Residential      1301.0   1340000.0
# 1                        16 Palisades  Residential      2788.0   2500000.0
# 2                   1615 Waverly Road  Residential      3250.0   3150000.0
# 3              2250 Indian Creek Road  Residential      7456.0   3090000.0
# 4                     317 E. Bayfront  Residential      2321.0  12725000.0
# ...                               ...          ...         ...         ...
# 616067            1691 Eden Plains Rd  Residential      2222.0    849000.0
# 616068           1561 Copper Penny Dr  Residential      3058.0   1375000.0
# 616069             21 Monte Vista Ave  Residential      1970.0    599888.0
# 616070               1242 Marshall Rd  Residential      1846.0    699000.0
# 616071             1626 Frisius Drive  Residential      1690.0    675800.0
#
#         DaysOnMarket                    ListOfficeName  ... NewConstructionYN  \
# 0                127           Rodeo Realty- Brentwood  ...             False
# 1                  1  Your Home Sold Guaranteed Realty  ...             False
# 2                  1                           COMPASS  ...               NaN
# 3                  0   Signature One Realty Group, Inc  ...             False
# 4                  2    Pacific Sotheby's Int'l Realty  ...             False
# ...              ...                               ...  ...               ...
# 616067             9          Zamora & Associates Inc.  ...             False
# 616068             3   Keller Williams San Diego Metro  ...             False
# 616069            24             KINGSHIP REALTY GROUP  ...             False
# 616070            32     Allison James Estates & Homes  ...             False
# 616071            79    Coldwell Banker Country Realty  ...             False
#
#         GarageSpaces     HighSchoolDistrict PostalCode AssociationFee  \
# 0                NaN                    NaN      90067        2105.00
# 1                3.0     Capistrano Unified      92677         254.00
# 2                2.0                    NaN      91108            NaN
# 3                4.0  Walnut Valley Unified      91765         295.95
# 4                2.0   Newport Mesa Unified      92662           0.00
# ...              ...                    ...        ...            ...
# 616067           2.0                    NaN      94513            NaN
# 616068           3.0                    NaN      91915         125.00
# 616069           0.0                    NaN      94590            NaN
# 616070           1.0                    NaN      91901            NaN
# 616071           0.0     Julian High School      92036           0.00
#
#        LotSizeSquareFeet              UnparsedAddress.1 year_month  Month  \
# 0               177861.0  2220 Avenue Of The Stars 2704 2024-01-01      1
# 1                 5300.0                   16 Palisades 2024-01-01      1
# 2                 9404.0              1615 Waverly Road 2024-01-01      1
# 3                58232.0         2250 Indian Creek Road 2024-01-01      1
# 4                 2250.0                317 E. Bayfront 2024-01-01      1
# ...                  ...                            ...        ...    ...
# 616067           20909.0            1691 Eden Plains Rd 2026-06-01      6
# 616068               NaN           1561 Copper Penny Dr 2026-06-01      6
# 616069            7405.0             21 Monte Vista Ave 2026-06-01      6
# 616070           37897.0               1242 Marshall Rd 2026-06-01      6
# 616071           28749.0             1626 Frisius Drive 2026-06-01      6
#
#         Year
# 0       2024
# 1       2024
# 2       2024
# 3       2024
# 4       2024
# ...      ...
# 616067  2026
# 616068  2026
# 616069  2026
# 616070  2026
# 616071  2026
#
# [533844 rows x 51 columns]

# %%
sold
# Out:
#                     Flooring ViewYN PoolPrivateYN  OriginalListPrice  \
# 0           Carpet,Tile,Wood   True         False           499000.0
# 1                        NaN  False         False           759900.0
# 2                        NaN  False         False           739900.0
# 3                        NaN   True         False          2100000.0
# 5                  Tile,Wood   True           NaN                NaN
# ...                      ...    ...           ...                ...
# 447959                   NaN   True         False          1388000.0
# 447960                   NaN   True          True           919900.0
# 447961       Carpet,Laminate    NaN         False           975000.0
# 447962  Carpet,Laminate,Wood   True         False           649999.0
# 447963                   NaN   True         False          6989995.0
#
#         ListingKey  CloseDate  ClosePrice   Latitude   Longitude  \
# 0        551985747 2024-01-26    240000.0  37.566106 -122.327954
# 1        522107581 2024-01-05    815000.0  32.659315 -117.096922
# 2        510919001 2024-01-05    810000.0  32.659284 -117.097174
# 3       1067652762 2024-01-02   2100000.0  35.277199 -120.646786
# 5       1061988701 2024-01-31   2340000.0  37.325454 -121.780303
# ...            ...        ...         ...        ...         ...
# 447959  1060097689 2026-06-30  13000000.0  34.117226 -118.372189
# 447960  1037789100 2026-06-30    850000.0  34.635955 -118.213539
# 447961  1035814040 2026-06-11    595000.0  37.824500 -122.281570
# 447962  1023191564 2026-06-30    615000.0  34.639233 -118.178343
# 447963  1014091927 2026-06-26   3000000.0  35.633015 -120.278054
#
#                 UnparsedAddress  ... AssociationFee  LotSizeSquareFeet  \
# 0          1 Baldwin Avenue 411  ...         6472.0                NaN
# 1                 2811 C Avenue  ...            NaN                NaN
# 2                 2812 C Avenue  ...            NaN                NaN
# 3           2054 Fixlini Street  ...            0.0            11219.0
# 5            3114 Rasmus Circle  ...            NaN             8712.0
# ...                         ...  ...            ...                ...
# 447959       2525 Thames Street  ...            0.0             7103.0
# 447960        4638 W Avenue M10  ...            0.0            30228.0
# 447961         3228 Magnolia St  ...            NaN             4389.0
# 447962      41614 27th Street W  ...            0.0           113797.0
# 447963  3160 Gillis Canyon Road  ...            0.0        106836562.8
#
#              BuyerAgentAOR        ListAgentAOR year_month Month  Year  \
# 0                      NaN                 NaN 2024-01-01     1  2024
# 1                      NaN                 NaN 2024-01-01     1  2024
# 2                      NaN                 NaN 2024-01-01     1  2024
# 3                      NaN                 NaN 2024-01-01     1  2024
# 5                      NaN                 NaN 2024-01-01     1  2024
# ...                    ...                 ...        ...   ...   ...
# 447959         TriCounties         TriCounties 2026-06-01     6  2026
# 447960           Southland           Southland 2026-06-01     6  2026
# 447961             Oakland             Oakland 2026-06-01     6  2026
# 447962           Southland           Southland 2026-06-01     6  2026
# 447963  NorthSanLuisObispo  NorthSanLuisObispo 2026-06-01     6  2026
#
#        listing_after_close_flag purchase_after_close_flag  \
# 0                         False                     False
# 1                         False                     False
# 2                         False                     False
# 3                         False                     False
# 5                         False                      True
# ...                         ...                       ...
# 447959                    False                     False
# 447960                    False                     False
# 447961                    False                     False
# 447962                    False                     False
# 447963                    False                     False
#
#        negative_timeline_flag
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 5                       False
# ...                       ...
# 447959                  False
# 447960                  False
# 447961                  False
# 447962                  False
# 447963                  False
#
# [443092 rows x 58 columns]

# %% [markdown]
# ### Dropping redundant columns
# - PropertyType: Assumed to be `Residential`
# - MlsStatus: Constant `Closed` value
# - ListingKey: Redundant with `ListingKeyNumeric`
# - year_month: Created `Month` and `Year` column

# %%
sold.drop(columns=["PropertyType", "MlsStatus", "ListingKey"], inplace=True)

# %%
sold.columns
# Out:
# Index(['Flooring', 'ViewYN', 'PoolPrivateYN', 'OriginalListPrice', 'CloseDate',
#        'ClosePrice', 'Latitude', 'Longitude', 'UnparsedAddress', 'LivingArea',
#        'ListPrice', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName',
#        'ListAgentFullName', 'BuyerAgentMlsId', 'BuyerAgentFirstName',
#        'BuyerAgentLastName', 'ListingKeyNumeric', 'MLSAreaMajor',
#        'CountyOrParish', 'AttachedGarageYN', 'ParkingTotal', 'PropertySubType',
#        'LotSizeAcres', 'BuyerOfficeAOR', 'YearBuilt', 'StreetNumberNumeric',
#        'ListingId', 'BathroomsTotalInteger', 'City', 'BedroomsTotal',
#        'ContractStatusChangeDate', 'PurchaseContractDate',
#        'ListingContractDate', 'StateOrProvince', 'FireplaceYN', 'Stories',
#        'Levels', 'LotSizeArea', 'MainLevelBedrooms', 'NewConstructionYN',
#        'GarageSpaces', 'HighSchoolDistrict', 'PostalCode', 'AssociationFee',
#        'LotSizeSquareFeet', 'BuyerAgentAOR', 'ListAgentAOR', 'year_month',
#        'Month', 'Year', 'listing_after_close_flag',
#        'purchase_after_close_flag', 'negative_timeline_flag'],
#       dtype='str')

# %% [markdown]
# ### row count check:
# - listing: `616072 -> 533844`
# - sold: `447964 -> 443092`

# %% [markdown]
# ### Basic analysis

# %%
analysis_columns = [
    "OriginalListPrice", "ListPrice", "LivingArea", "DaysOnMarket",
    "LotSizeAcres", "YearBuilt", "BedroomsTotal",
    "BathroomsTotalInteger", "Year"
]
sold_analysis_columns = analysis_columns + ["ClosePrice"]

def basic_stats(df, columns):
    stats = df[columns].describe().T
    iqr = stats["75%"] - stats["25%"]
    lower = stats["25%"] - 1.5 * iqr
    upper = stats["75%"] + 1.5 * iqr
    stats["NaN"] = df[columns].isna().sum()
    stats["IQR outliers"] = (df[columns].lt(lower) | df[columns].gt(upper)).sum()
    return stats

# %% [markdown]
# ### NaN counts

# %%
listing.isna().sum().sort_values(ascending=False).to_frame("listing NaN")
# Out:
#                           listing NaN
# MainLevelBedrooms              229886
# HighSchoolDistrict             156646
# AssociationFee                 119358
# AttachedGarageYN                96678
# Stories                         84187
# MLSAreaMajor                    61650
# Levels                          48141
# NewConstructionYN               42212
# LotSizeAcres                    39689
# LotSizeSquareFeet               38953
# LotSizeArea                     38767
# GarageSpaces                    33858
# ContractStatusChangeDate         7058
# ListAgentFirstName.1             3396
# PropertySubType                  1084
# YearBuilt                         918
# StreetNumberNumeric               888
# UnparsedAddress.1                 755
# UnparsedAddress                   755
# OriginalListPrice                 633
# FireplaceYN                       577
# City                              338
# ListAgentFullName                 107
# ListAgentLastName.1                38
# ParkingTotal                        6
# PostalCode                          6
# StateOrProvince                     1
# Latitude.1                          0
# year_month                          0
# Month                               0
# ListPrice.1                         0
# ListingId                           0
# ListingContractDate                 0
# ListingKeyNumeric                   0
# Latitude                            0
# Longitude                           0
# PropertyType                        0
# LivingArea                          0
# ListPrice                           0
# DaysOnMarket                        0
# ListOfficeName                      0
# CountyOrParish                      0
# Longitude.1                         0
# PropertyType.1                      0
# MlsStatus                           0
# DaysOnMarket.1                      0
# LivingArea.1                        0
# ListingKey                          0
# BathroomsTotalInteger               0
# BedroomsTotal                       0
# Year                                0

# %%
sold.isna().sum().sort_values(ascending=False).to_frame("sold NaN")
# Out:
#                            sold NaN
# MainLevelBedrooms            183431
# Flooring                     159058
# HighSchoolDistrict           120721
# AssociationFee               100147
# AttachedGarageYN              67566
# Stories                       66601
# BuyerAgentAOR                 61885
# MLSAreaMajor                  58642
# ListAgentAOR                  53714
# Levels                        41162
# ViewYN                        37116
# PoolPrivateYN                 36882
# LotSizeAcres                  33766
# NewConstructionYN             33386
# LotSizeSquareFeet             33338
# LotSizeArea                   33206
# BuyerOfficeAOR                26609
# GarageSpaces                  19106
# BuyerOfficeName                6867
# BuyerAgentFirstName            2032
# PropertySubType                 825
# OriginalListPrice               785
# BuyerAgentMlsId                 585
# ContractStatusChangeDate        584
# StreetNumberNumeric             435
# ParkingTotal                    421
# YearBuilt                       362
# UnparsedAddress                 345
# FireplaceYN                     314
# City                            297
# PurchaseContractDate            196
# BuyerAgentLastName              190
# ListAgentFullName                96
# PostalCode                        3
# ListingContractDate               1
# StateOrProvince                   1
# Longitude                         0
# year_month                        0
# Month                             0
# Year                              0
# CloseDate                         0
# listing_after_close_flag          0
# ClosePrice                        0
# Latitude                          0
# purchase_after_close_flag         0
# DaysOnMarket                      0
# LivingArea                        0
# ListPrice                         0
# ListOfficeName                    0
# ListingKeyNumeric                 0
# BedroomsTotal                     0
# BathroomsTotalInteger             0
# ListingId                         0
# CountyOrParish                    0
# negative_timeline_flag            0

# %% [markdown]
# ### Statistics and outliers

# %%
basic_stats(listing, analysis_columns).rename_axis("listing")
# Out:
#                           count          mean           std     min  \
# listing
# OriginalListPrice      533211.0  1.397368e+06  7.684759e+06     0.0
# ListPrice              533844.0  1.310332e+06  2.392777e+06     1.0
# LivingArea             533844.0  1.987000e+03  2.332991e+04     0.0
# DaysOnMarket           533844.0  1.891923e+01  2.645658e+01     0.0
# LotSizeAcres           494155.0  6.569366e+01  1.212734e+04     0.0
# YearBuilt              532926.0  1.979763e+03  2.690247e+01  1776.0
# BedroomsTotal          533844.0  3.226656e+00  1.194927e+00     0.0
# BathroomsTotalInteger  533844.0  2.638156e+00  3.276414e+00     0.0
# Year                   533844.0  2.024955e+03  7.570955e-01  2024.0
#
#                                25%        50%           75%           max  \
# listing
# OriginalListPrice      579000.0000  839000.00  1.375000e+06  1.749000e+09
# ListPrice              575000.0000  829999.00  1.350000e+06  4.000000e+08
# LivingArea               1250.0000    1676.00  2.307000e+03  1.702132e+07
# DaysOnMarket                5.0000      11.00  2.200000e+01  1.063000e+03
# LotSizeAcres                0.1218       0.17  3.279000e-01  4.187292e+06
# YearBuilt                1961.0000    1980.00  2.001000e+03  2.028000e+03
# BedroomsTotal               2.0000       3.00  4.000000e+00  1.080000e+02
# BathroomsTotalInteger       2.0000       2.00  3.000000e+00  2.208000e+03
# Year                     2024.0000    2025.00  2.026000e+03  2.026000e+03
#
#                          NaN  IQR outliers
# listing
# OriginalListPrice        633         45471
# ListPrice                  0         45315
# LivingArea                 0         26700
# DaysOnMarket               0         44513
# LotSizeAcres           39689         79663
# YearBuilt                918          1181
# BedroomsTotal              0          1740
# BathroomsTotalInteger      0         34433
# Year                       0             0

# %%
basic_stats(sold, sold_analysis_columns).rename_axis("sold")
# Out:
#                           count          mean           std     min  \
# sold
# OriginalListPrice      442307.0  1.225164e+06  6.758995e+06     0.0
# ListPrice              443092.0  1.139379e+06  1.329657e+06   525.0
# LivingArea             443092.0  1.905422e+03  2.558806e+04     0.0
# DaysOnMarket           443092.0  3.736555e+01  5.363463e+01     0.0
# LotSizeAcres           409326.0  6.251422e+01  1.544597e+04     0.0
# YearBuilt              442730.0  1.978599e+03  2.628610e+01  1776.0
# BedroomsTotal          443092.0  3.206255e+00  1.065502e+00     0.0
# BathroomsTotalInteger  443092.0  2.537913e+00  1.098947e+00     0.0
# Year                   443092.0  2.024787e+03  7.510765e-01  2024.0
# ClosePrice             443092.0  1.189206e+06  6.083892e+06     0.0
#
#                                25%          50%          75%           max  \
# sold
# OriginalListPrice      585000.0000  826000.0000  1299000.000  1.390000e+09
# ListPrice              575000.0000  818000.0000  1295000.000  1.375000e+08
# LivingArea               1249.0000    1647.0000     2225.000  1.702132e+07
# DaysOnMarket                8.0000      18.0000       48.000  1.243000e+04
# LotSizeAcres                0.1202       0.1668        0.275  7.810698e+06
# YearBuilt                1960.0000    1979.0000     1999.000  2.027000e+03
# BedroomsTotal               3.0000       3.0000        4.000  4.500000e+01
# BathroomsTotalInteger       2.0000       2.0000        3.000  1.530000e+02
# Year                     2024.0000    2025.0000     2025.000  2.026000e+03
# ClosePrice             575000.0000  824500.0000  1300000.000  9.895000e+08
#
#                          NaN  IQR outliers
# sold
# OriginalListPrice        785         34572
# ListPrice                  0         33164
# LivingArea                 0         19372
# DaysOnMarket               0         33823
# LotSizeAcres           33766         63641
# YearBuilt                362          1033
# BedroomsTotal              0         24110
# BathroomsTotalInteger      0         20461
# Year                       0             0
# ClosePrice                 0         32983

# %% [markdown]
# ### Distributions
# Values are clipped at the 99th percentile for readability.

# %%
listing[analysis_columns].clip(
    upper=listing[analysis_columns], axis=1
).hist(bins=30, figsize=(12, 8))
plt.suptitle("Listing distributions", y=1.02)
plt.tight_layout()
plt.show()

# %%
listing[analysis_columns].clip(
    upper=listing[analysis_columns].quantile(0.99), axis=1
).hist(bins=30, figsize=(12, 8))
plt.suptitle("Listing distributions", y=1.02)
plt.tight_layout()
plt.show()

# %%
sold[sold_analysis_columns].clip(
    upper=sold[sold_analysis_columns], axis=1
).hist(bins=30, figsize=(12, 8))
plt.suptitle("Sold distributions", y=1.02)
plt.tight_layout()
plt.show()

# %%
sold[sold_analysis_columns].clip(
    upper=sold[sold_analysis_columns].quantile(0.99), axis=1
).hist(bins=30, figsize=(12, 8))
plt.suptitle("Sold distributions", y=1.02)
plt.tight_layout()
plt.show()
